# %% [markdown]
# Homework 1: Introduction to Machine Learning

# %% [markdown]
# Deadline:
# 28 September 2026 (Mon), 19:00

# %% [markdown]
# Questions
# Answer the questions below to complete your homework.

# %% [markdown]
# 1. Pandas version (1 point)

# %%
import pandas as pd
import numpy as np

# %%
print(pd.__version__)
# Out:
# 3.0.6

# %% [markdown]
# 2. Records count (1 point)
#
#
# [ ] 5000
#
# [ ] 9000
#
# [x] 10000
#
# [ ] 15000

# %%
df = pd.read_csv("car_fuel_efficiency_2026.csv")
print(df.shape[0])
# Out:
# 10000

# %% [markdown]
# 3. Fuel types (1 point)
#
#
# [ ] 1
#
# [ ] 2
#
# [x] 3
#
# [ ] 4

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %% [markdown]
# 4. Missing values (1 point)
#
#
# [] 0
#
# [ ] 1
#
# [x] 2
#
# [ ] 3
#
# [ ] 4

# %%
miss_col = df.isnull().sum()
int(miss_col[miss_col > 0].count())
# Out:
# 2

# %% [markdown]
# 5. Max fuel efficiency (1 point)
#
#
# [ ] 21.2
#
# [ ] 31.2
#
# [x] 41.2
#
# [ ] 51.2

# %%
float(df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max())
# Out:
# 41.2

# %% [markdown]
# 6. Median value of horsepower (1 point)
#
#
# [ ] Yes, it increased
#
# [x] Yes, it decreased
#
# [ ] No

# %%
med_1 = int(df['horsepower'].median())

# %% [markdown]
# 1. Find the median value of the `horsepower` column in the dataset.

# %% [markdown]
# 2. Next, calculate the most frequent value of the same `horsepower` column.

# %%
fil_mis = df['horsepower'].mode()[0]

# %%
med_2 = int(df['horsepower'].fillna(fil_mis).median())

# %%
med_2
# Out:
# 252

# %% [markdown]
# ## Q7. Sum of weights
#
# 1. Select all the cars from Asia
# 2. Select only columns `vehicle_weight` and `model_year`
# 3. Select the first 7 values
# 4. Get the underlying NumPy array. Let's call it `X`.
# 5. Compute matrix-matrix multiplication between the transpose of `X` and `X`.
#    To get the transpose, use `X.T`. Let's call the result `XTX`.
# 6. Invert `XTX`.
# 7. Create an array `y` with values `[1100, 1300, 800, 900, 1000, 1100, 1200]`.
# 8. Multiply the inverse of `XTX` with the transpose of `X`, and then multiply
#    the result by `y`. Call the result `w`.
# 9. What's the sum of all the elements of the result?
#
# - 0.0369
# - 0.369
# - 3.69
# - 36.9

# %%
df = pd.read_csv("car_fuel_efficiency_2026.csv")
asia = df[df["origin"] == "Asia"]
asia
# Out:
#       model_year origin fuel_type         drivetrain  num_doors  \
# 2           1996   Asia  Gasoline  Front-wheel drive          5
# 6           1992   Asia  Gasoline  Front-wheel drive          2
# 8           1997   Asia  Gasoline   Rear-wheel drive          3
# 10          1978   Asia  Gasoline    All-wheel drive          3
# 15          2007   Asia    Diesel  Front-wheel drive          4
# ...          ...    ...       ...                ...        ...
# 9984        2011   Asia  Gasoline  Front-wheel drive          3
# 9987        2004   Asia    Diesel    All-wheel drive          3
# 9990        1975   Asia    Diesel  Front-wheel drive          4
# 9994        1993   Asia  Gasoline   Rear-wheel drive          2
# 9996        1993   Asia  Gasoline    All-wheel drive          2
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 2                    2320              6       267.0            4240
# ...

# %%
import numpy as np

# %%
first7 = asia[['vehicle_weight','model_year']].head(7)
first7
X = np.array(first7)
X.T
XTX = X.T @ X

# %%
XTX
# Out:
# array([[131950500,  60750580],
#        [ 60750580,  28041424]])

# %%
XTX_inv = np.linalg.inv(XTX)
XTX_inv
# Out:
# array([[ 2.96830537e-06, -6.43071025e-06],
#        [-6.43071025e-06,  1.39675281e-05]])

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])
w = XTX_inv @ X.T @ y
float(w.sum())
# Out:
# 0.36919696904925486

# %%
w.shape
w
# Out:
# array([0.13644777, 0.2327492 ])
